# %%
from voxel import *

# %% [markdown]
# # Gaussians

# %% [markdown]
# ## Numerical Approximations

# %%
def get_2D_gaussian(mus, sigma, K, A):
    def s(v):
        x = v[0]
        y = v[1]
        
        f = 0.
        for kx in np.arange(-K,K+1):
            for ky in np.arange(-K,K+1):
                for mu in mus:
                    Ak = A.dot([kx,ky])
                    mx = Ak[0]+mu[0]
                    my = Ak[1]+mu[1]
                    f += np.exp(-((x - mx)**2 + (y - my)**2) / (2*sigma**2))
            
        return f / (2*np.pi * sigma**2)
    
    return s

# %% [markdown]
# ### Centered in Unit Cell

# %%
A = np.eye(2)
gauss = get_2D_gaussian(np.array([[0.5,0.5]]), 0.25, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ### Corner of Unit Cell

# %%
A = np.eye(2)
gauss = get_2D_gaussian(np.array([[0.,0.]]), 0.25, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-93a61aff727c> in <module>
#       4 plot_2D_realspace_lattice(A, xi, sr)
#       5 plot_2D_bravais_lattice(A, xi, sr)
# ----> 6 B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
#       7 plot_2D_reciprocal_lattice(B, mi, sg)
#
# ~/Documents/VoxelCNN/voxel.py in reciprocal_lattice(s, A, n, g0, g1)
#      45     E = np.exp(-1j * XR) # (n*n, m*m)
#      46
# ---> 47     SR = np.apply_along_axis(s, 0, R) # apply field column-wise, (n*n,)
#      48
#      49     delta = (xi[1] - xi[0])**d
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400     buff[ind0] = res
#     401     for ind in inds:
# --> 402         buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     403
#     404     if not isinstance(res, matrix):
#
# <ipython-input-2-6154b12c800b> in s(v)
#      11                     mx = Ak[0]+mu[0]
#      12                     my = Ak[1]+mu[1]
# ---> 13                     f += np.exp(-((x - mx)**2 + (y - my)**2) / (2*sigma**2))
#      14
#      15         return f / (2*np.pi * sigma**2)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Different Basis

# %%
A = np.array([
    [1., 1.],
    [0., 1.]
])
gauss = get_2D_gaussian(np.array([[0.,0.]]), 0.25, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %%
A = np.eye(2)*2
gauss = get_2D_gaussian(np.array([[0.,0.]]), 0.25, 3, np.eye(2))
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ### Custom Points

# %%
A = np.eye(2)
gauss = get_2D_gaussian(np.array([[0.,0.], [0.5,0.15]]), 0.1, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %%
A = np.eye(2)*2
gauss = get_2D_gaussian(np.array([[0.,0.], [0.5,0.15]]), 0.1, 3, np.eye(2))
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice(gauss, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ## Theoretical Fourier Transform

# %% [markdown]
# ### Centered in Unit Cell

# %%
A = np.eye(2)
sigma = 0.25
mus = np.array([[0.5,0.5]])
gauss = get_2D_gaussian(mus, sigma, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice_gaussian(A, mus, sigma, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ### Corner in Unit Sphere and Different Basis

# %%
A = np.array([
    [1., 1.],
    [0., 1.]
])
sigma = 0.25
mus = np.array([[0.,0.]])
gauss = get_2D_gaussian(mus, sigma, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice_gaussian(A, mus, sigma, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ### Custom Points

# %%
A = np.eye(2)
mus = np.array([[0.,0.], [0.5,0.15]])
sigma = 0.1
gauss = get_2D_gaussian(mus, sigma, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice_gaussian(A, mus, sigma, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %%
A = np.eye(2)*2
mus = np.array([
    [0., 0.],
    [0.5, 0.1],
    [0., 1.],
    [1., 0.],
    [1.5, 0.1],
    [0.5, 1.1],
    [1.5, 1.1],
    [1.,1.]
])
sigma = 0.1
gauss = get_2D_gaussian(mus, sigma, 3, A)
xi, sr = bravais_lattice(gauss, A)
plot_2D_realspace_lattice(A, xi, sr)
plot_2D_bravais_lattice(A, xi, sr)
B, mi, sg = reciprocal_lattice_gaussian(A, mus, sigma, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)

# %% [markdown]
# ### 3D

# %%
B, mi, sg = reciprocal_lattice_gaussian(np.eye(3), np.array([[0.,0.,0.]]), 0.1, g0=-8, g1=8)
# %matplotlib notebook
plot_3D_reciprocal_lattice(B, mi, sg)
