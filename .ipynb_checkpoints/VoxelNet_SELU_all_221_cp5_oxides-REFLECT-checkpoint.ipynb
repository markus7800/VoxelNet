# %%
import numpy as np
import pandas as pd

from molloader import *
from ML_utils import *

import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split, KFold, ParameterGrid

# %%
def drop_duplicates(df):
    df = df.drop_duplicates(subset="compound", keep="first")
    print("Number of molecules", df.shape[0])
    return df

# %%
def get_all_elements(df):
      return np.unique(np.hstack(np.array(df.species)))

# %%
class VoxelNet(nn.Module):
    def __init__(self, in_channels=1):
        super().__init__()
        # (N, C, D, H, W)
        self.conv1 = nn.Sequential(
            nn.Conv3d(in_channels, 16, 3, padding=0, stride=1),
            nn.SELU(0.3),
            nn.MaxPool3d(2))
        
        self.conv2 = nn.Sequential(
            nn.Conv3d(16, 16, 3, padding=0, stride=1),
            nn.SELU(),
            nn.MaxPool3d(2))
        
        self.conv3 = nn.Sequential(
            nn.Conv3d(16, 16, 3, padding=0, stride=1),
            nn.SELU())
        
        self.regressor = nn.Sequential(nn.Flatten(),
                                        nn.Linear(1024, 32),
                                        nn.SELU(),
                                        nn.Linear(32, 8),
                                        nn.SELU(),
                                        nn.Linear(8, 1))
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.regressor(x)
        return x

# %%
data_name = "all_221_cp5_3_species_oxides"
fig_folder = "plots_SELU/"

# %%
df = pd.read_pickle(f"data/{data_name}.pkl")
df = drop_duplicates(df)
df
# Out:
# Number of molecules 1983
#                         auid  \
# 0     aflow:b778fabdb1b01db1
# 2     aflow:272cd0e74db84a51
# 4     aflow:7e6bdbc495310b44
# 6     aflow:c0e1c25976bb4c75
# 8     aflow:3b79b8b28a5d5cc1
# ...                      ...
# 3947  aflow:e243d024b0749ac0
# 3949  aflow:ae4a07b2d68c2933
# 3951  aflow:0d9d3ce033a32aae
# 3953  aflow:627232532ed2fb40
# 3955  aflow:2b3ea96a80ac45cd
#
#                                                    aurl  compound composition  \
# 0     aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgAlO/T00...  Ag1Al1O3   [1, 1, 3]
# 2     aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgAsO/T00...  Ag1As1O3   [1, 1, 3]
# 4     aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgAuO/T00...  Ag1Au1O3   [1, 1, 3]
# 6     aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgB_hO/T0...   Ag1B1O3   [1, 1, 3]
# 8     aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgBa_svO/...  Ag1Ba1O3   [1, 1, 3]
# ...                                                 ...       ...         ...
# 3947  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/OXeZn/T00...  O3Xe1Zn1   [3, 1, 1]
# 3949  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/OXeZr_sv/...  O3Xe1Zr1   [3, 1, 1]
# 3951  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/OY_svZn/T...   O3Y1Zn1   [3, 1, 1]
# 3953  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/OY_svZr_s...   O3Y1Zr1   [3, 1, 1]
# 3955  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/OZnZr_sv/...  O3Zn1Zr1   [3, 1, 1]
#
#           species natoms spacegroup pearson_symbol  \
# 0     [Ag, Al, O]      5        221            cP5
# 2     [Ag, As, O]      5        221            cP5
# 4     [Ag, Au, O]      5        221            cP5
# 6      [Ag, B, O]      5        221            cP5
# 8     [Ag, Ba, O]      5        221            cP5
# ...           ...    ...        ...            ...
# 3947  [O, Xe, Zn]      5        221            cP5
# 3949  [O, Xe, Zr]      5        221            cP5
# 3951   [O, Y, Zn]      5        221            cP5
# 3953   [O, Y, Zr]      5        221            cP5
# 3955  [O, Zn, Zr]      5        221            cP5
#
#                                                geometry  \
# 0     [3.7688035, 3.7688035, 3.7688035, 90.0, 90.0, ...
# 2     [3.7951634, 3.7951634, 3.7951634, 90.0, 90.0, ...
# 4     [4.1003175, 4.1003175, 4.1003175, 90.0, 90.0, ...
# 6      [3.484261, 3.484261, 3.484261, 90.0, 90.0, 90.0]
# 8     [4.7271734, 4.7271734, 4.7271734, 90.0, 90.0, ...
# ...                                                 ...
# 3947   [4.370543, 4.370543, 4.370543, 90.0, 90.0, 90.0]
# 3949   [4.322477, 4.322477, 4.322477, 90.0, 90.0, 90.0]
# 3951  [4.3517566, 4.3517566, 4.3517566, 90.0, 90.0, ...
# 3953   [4.155165, 4.155165, 4.155165, 90.0, 90.0, 90.0]
# 3955   [3.723766, 3.723766, 3.723766, 90.0, 90.0, 90.0]
#
#                                    positions_fractional  \
# 0     [[0.0, 0.0, 0.0], [0.5, 0.5, 0.5], [0.0, 0.5, ...
# 2     [[0.0, 0.0, 0.0], [0.5, 0.5, 0.5], [0.0, 0.5, ...
# 4     [[0.0, 0.0, 0.0], [0.5, 0.5, 0.5], [0.0, 0.5, ...
# 6     [[0.0, 0.0, 0.0], [0.5, 0.5, 0.5], [0.0, 0.5, ...
# 8     [[-0.0, 0.0, -0.0], [0.5, 0.5, 0.5], [-0.0, 0....
# ...                                                 ...
# 3947  [[0.0, 0.5, 0.5], [0.5, 0.0, 0.5], [0.5, 0.5, ...
# 3949  [[0.0, 0.5, 0.5], [0.5, 0.0, 0.5], [0.5, 0.5, ...
# 3951  [[0.0, 0.5, 0.5], [0.5, 0.0, 0.5], [0.5, 0.5, ...
# 3953  [[0.0, 0.5, 0.5], [0.5, 0.0, 0.5], [0.5, 0.5, ...
# 3955  [[0.0, 0.5, 0.5], [0.5, 0.0, 0.5], [0.5, 0.5, ...
#
#                                     positions_cartesian  enthalpy_atom  \
# 0     [[0.0, 0.0, 0.0], [1.8844, 1.8844, 1.8844], [0...       -5.04863
# 2     [[0.0, 0.0, 0.0], [1.89758, 1.89758, 1.89758],...       -4.55519
# 4     [[0.0, 0.0, 0.0], [2.05016, 2.05016, 2.05016],...       -2.80408
# 6     [[0.0, 0.0, 0.0], [1.74213, 1.74213, 1.74213],...       -4.55549
# 8     [[-0.0, 0.0, -0.0], [2.36359, 2.36359, 2.36359...       -3.52096
# ...                                                 ...            ...
# 3947  [[0.0, 2.18527, 2.18527], [2.18527, 0.0, 2.185...       -1.89960
# 3949  [[-0.0, 2.16124, 2.16124], [2.16124, -0.0, 2.1...       -5.89112
# 3951  [[0.0, 2.17588, 2.17588], [2.17588, 0.0, 2.175...       -5.57716
# 3953  [[0.0, 2.07758, 2.07758], [2.07758, 0.0, 2.077...       -8.70129
# 3955  [[-0.0, 1.86188, 1.86188], [1.86188, -0.0, 1.8...       -6.45445
#
#      enthalpy_formation_atom
# 0                  -0.775736
# 2                  -0.100528
# 4                    1.37453
# 6                    0.30734
# 8                   0.388015
# ...                      ...
# 3947                    None
# 3949                  -1.222
# 3951                -1.07268
# 3953                -2.74124
# 3955                    None
#
# [1983 rows x 13 columns]

# %%
elem_counts = pd.Series(np.hstack(np.array(df.species))).value_counts()
low_freq = elem_counts[elem_counts < 50].index.values
low_freq_mask = df.species.apply(lambda s: len(np.setdiff1d(s, low_freq)) < len(s))
df = df[~low_freq_mask]

# %%
elements = get_all_elements(df)
nchannel = len(elements)
nchannel, elements
# Out:
# (79,
#  array(['Ag', 'Al', 'As', 'Au', 'B', 'Ba', 'Be', 'Bi', 'Br', 'C', 'Ca',
#         'Cd', 'Ce', 'Cl', 'Co', 'Cr', 'Cs', 'Cu', 'Dy', 'Er', 'Eu', 'F',
#         'Fe', 'Ga', 'Gd', 'Ge', 'Hf', 'Hg', 'Ho', 'I', 'In', 'Ir', 'K',
#         'La', 'Li', 'Lu', 'Mg', 'Mn', 'Mo', 'N', 'Na', 'Nb', 'Nd', 'Ni',
#         'O', 'Os', 'P', 'Pa', 'Pb', 'Pd', 'Pr', 'Pt', 'Pu', 'Rb', 'Re',
#         'Rh', 'Ru', 'S', 'Sb', 'Sc', 'Se', 'Si', 'Sn', 'Sr', 'Ta', 'Tb',
#         'Tc', 'Te', 'Th', 'Ti', 'Tl', 'U', 'V', 'W', 'Xe', 'Y', 'Yb', 'Zn',
#         'Zr'], dtype='<U2'))

# %%
net = VoxelNet(nchannel)
count_parameters(net)
# Out:
# 81073

# %% [markdown]
# ## Parameters

# %%
sigma = 0.1
L = 10
N = 32
epochs = 50
weight_decay = 0.01

device = get_default_device()

# %% [markdown]
# ##  Cartesian

# %%
seed_everything()
train_df, test_df = train_test_split(df, test_size=0.1)
print(train_df.shape, test_df.shape)

seed_everything()

net = VoxelNet(nchannel)
net = net.to(device)

ml_train = MolLoader(train_df, sigma=sigma, elements=elements,
                     L=L, N=N, batch_size=64, nchannel=nchannel,
                     shuffle=True, rotate_randomly=True, reflect_randomly=True,
                     reduce_data=True, device=device, mode='cartesian')

ml_test = MolLoader(test_df, sigma=sigma, elements=elements,
                    L=L, N=N, batch_size=128, nchannel=nchannel,
                    shuffle=False, rotate_randomly=False, reflect_randomly=False,
                    device=device, reduce_data=True, mode='cartesian')

fit(epochs, net, ml_train, ml_test, torch.optim.Adam, lr=0.001, weight_decay=weight_decay)
# Out:
# (1784, 13) (199, 13)
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Epoch 0: train loss 9.038620948791504 val loss 3.422407388687134
# Epoch 1: train loss 2.19482421875 val loss 2.2126054763793945
# Epoch 2: train loss 1.9815481901168823 val loss 2.0187153816223145
# Epoch 3: train loss 1.7635703086853027 val loss 1.8403136730194092
# Epoch 4: train loss 1.1727802753448486 val loss 0.610168993473053
# Epoch 5: train loss 0.4705706238746643 val loss 0.5351516604423523
# Epoch 6: train loss 0.41289475560188293 val loss 0.6727397441864014
# Epoch 7: train loss 0.41665974259376526 val loss 0.6454703211784363
# Epoch 8: train loss 0.4054141342639923 val loss 0.6812964677810669
# Epoch 9: train loss 0.3843036890029907 val loss 0.5860978960990906
ys, y_hats = predict(net, ml_pred)
plot_predictions(ys, y_hats)
plt.show()

# %%
# 0.0431 50 epoch wd=0, L=12.8
# 0.0893 50 epoch wd=0.01, L=10 drop_low_freq
# 0.0850 50 epoch wd=0.01, L=10
# transformations
seed_everything()
ml_pred = ml_train
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
print("Mean Variance: ", np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
plot_predictions(ys, y_hats, alpha=0.01)
plt.savefig(fig_folder + data_name + "_cartesian_train.pdf")
# Out:
# Mean Variance:  0.007820886

# %% [markdown]
# ### Test Plots

# %%
# 0.2951 50 epoch wd=0, L=12.8
# 0.2933 50 epoch wd=0.01, L=10 drop_low_freq
# 0.3349 50 epoch wd=0.01, L=10
ml_pred = ml_test
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=False, reflect_randomly=False)
ys, y_hats = predict(net, ml_pred)
plot_predictions(ys, y_hats)
plt.show()

# %%
# 0.2726 50 epoch wd=0, L=12.8
# 0.1803 50 epoch wd=0.01, L=10
# 0.2504 50 epoch wd=0.01, L=10
# transformations
seed_everything()
ml_pred = ml_test
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
print("Mean Variance: ", np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
plot_predictions(ys, y_hats)
plt.savefig(fig_folder + data_name + "_cartesian_test.pdf")
# Out:
# Mean Variance:  0.009452865

# %% [markdown]
# ## Spherical

# %%
seed_everything()
train_df, test_df = train_test_split(df, test_size=0.1)
print(train_df.shape, test_df.shape)

seed_everything()

net = VoxelNet(nchannel)
net = net.to(device)

ml_train = MolLoader(train_df, sigma=sigma, elements=elements,
                     L=L, N=N, batch_size=64, nchannel=nchannel,
                     shuffle=True, rotate_randomly=True, reflect_randomly=True,
                     reduce_data=True, device=device, mode='spherical')

ml_test = MolLoader(test_df, sigma=sigma, elements=elements,
                    L=L, N=N, batch_size=128, nchannel=nchannel,
                    shuffle=False, rotate_randomly=False, reflect_randomly=False,
                    device=device, reduce_data=True, mode='spherical')

fit(epochs, net, ml_train, ml_test, torch.optim.Adam, lr=0.001, weight_decay=0)
# Out:
# (1784, 13) (199, 13)
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=spherical, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=spherical, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Epoch 0: train loss 9.009493827819824 val loss 3.332409143447876
# Epoch 1: train loss 2.0872788429260254 val loss 2.0474841594696045
# Epoch 2: train loss 1.647132396697998 val loss 1.3599146604537964
# Epoch 3: train loss 0.7313228249549866 val loss 0.6190248131752014
# Epoch 4: train loss 0.44663161039352417 val loss 0.4744367301464081
# Epoch 5: train loss 0.3788250982761383 val loss 0.491331547498703
# Epoch 6: train loss 0.35878947377204895 val loss 0.5180203318595886
# Epoch 7: train loss 0.36867213249206543 val loss 0.46741029620170593
# 0.1183 50 epoch wd=0.01, L=10
ml_pred = ml_train
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=False, reflect_randomly=False)
ys, y_hats = predict(net, ml_pred)
plot_predictions(ys, y_hats)
plt.show()

# %%
# 0.0932 50 epoch wd=0, L=12.8
# 0.1074 50 epoch wd=0.01, L=10
# transformations
seed_everything()
ml_pred = ml_train
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
print("Mean Variance: ", np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
plot_predictions(ys, y_hats, alpha=0.01)
plt.savefig(fig_folder + data_name + "_spherical_train.pdf")
# Out:
# Mean Variance:  0.00023915549

# %% [markdown]
# ### Test Plots

# %%
# 0.3033 50 epoch wd=0, L=12.8
# 0.1900 50 epoch wd=0.01, L=10 drop_low_freq
# 0.3133 50 epoch wd=0.01, L=10
ml_pred = ml_test
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=False, reflect_randomly=False)
ys, y_hats = predict(net, ml_pred)
plot_predictions(ys, y_hats)
plt.show()

# %%
# 0.3018 50 epoch wd=0, L=12.8
# 0.1784 50 epoch wd=0.01, L=10 drop_low_freq !!
# 0.3085 50 epoch wd=0.01, L=10
# transformations
seed_everything()
ml_pred = ml_test
ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
print("Mean Variance: ", np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
plot_predictions(ys, y_hats)
plt.savefig(fig_folder + data_name + "_spherical_test.pdf")
# Out:
# Mean Variance:  0.00025902895

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# ### Cartesian

# %%
seed_everything()
all_ys = []
all_y_hats = []
all_vars = []

all_train_ys = []
all_train_y_hats = []
all_train_vars = []

for train_indices, test_indices in KFold(n_splits=5, shuffle=True).split(df):
    
    train_df = df.iloc[train_indices]
    test_df = df.iloc[test_indices]

    net = VoxelNet(nchannel)
    net = net.to(device)
    
    ml_train = MolLoader(train_df, sigma=sigma, elements=elements,
                     L=L, N=N, batch_size=64, nchannel=nchannel,
                     shuffle=True, rotate_randomly=True, reflect_randomly=True,
                     reduce_data=True, device=device, mode='cartesian')

    ml_test = MolLoader(test_df, sigma=sigma, elements=elements,
                    L=L, N=N, batch_size=128, nchannel=nchannel,
                    shuffle=False, rotate_randomly=False, reflect_randomly=False,
                    device=device, reduce_data=True, mode='cartesian')
    
    fit(epochs, net, ml_train, ml_test, torch.optim.Adam, lr=0.001, weight_decay=0)
    
    ml_pred = ml_train
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys, y_hats)
    plt.show()
    all_train_ys.append(ys)
    all_train_y_hats.append(y_hats)
    all_train_vars.append(np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
    
    ml_pred = ml_test
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys, y_hats)
    plt.show()
    all_ys.append(ys)
    all_y_hats.append(y_hats)
    all_vars.append(np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
# Out:
# Initialised MolLoader with 1586 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with
# Epoch 17: train loss 0.2668737769126892 val loss 0.3533531725406647
# Epoch 18: train loss 0.2261987179517746 val loss 0.324461966753006
# Epoch 19: train loss 0.22550278902053833 val loss 0.3351835310459137
# Epoch 20: train loss 0.20596623420715332 val loss 0.3291790783405304
# Epoch 21: train loss 0.1927671730518341 val loss 0.3758084177970886
# Epoch 22: train loss 0.17488202452659607 val loss 0.3334725797176361
# Epoch 23: train loss 0.1571275293827057 val loss 0.3193301558494568
# Epoch 24: train loss 0.1530357003211975 val loss 0.2948915958404541
# Epoch 25: train loss 0.13642702996730804 val loss 0.30298444628715515
# Epoch 26: train loss 0.14704188704490662 val loss 0.3191800117492676
# Epoch 27: train loss 0.13744284212589264 val loss 0.30452054738998413
# Epoch 28: train loss 0.132621631026268 val loss 0.2789323329925537
# Epoch 29: train loss 0.10306961089372635 val loss 0.31877756118774414
# Epoch 30: train loss 0.1320348083972931 val loss 0.26936331391334534
# Epoch 31: train loss 0.10435986518859863 val loss 0.29610878229141235
# Epoch 32: train loss 0.09328906238079071 val loss 0.2745935916900635
# Epoch 33: train loss 0.09067036956548691 val loss 0.2733580470085144
# Epoch 34: train loss 0.07456090301275253 val loss 0.26292476058006287
# Epoch 35: train loss 0.09115514159202576 val loss 0.2998940050601959
# Epoch 36: train loss 0.0813160315155983 val loss 0.2587548494338989
# Epoch 37: train loss 0.06088550016283989 val loss 0.2634546756744385
# Epoch 38: train loss 0.07318353652954102 val loss 0.2684336304664612
# Epoch 39: train loss 0.07824128121137619 val loss 0.28656458854675293
# Epoch 40: train loss 0.07035186886787415 val loss 0.2784196436405182
# Epoch 41: train loss 0.0580037422478199 val loss 0.2563398778438568
# Epoch 42: train loss 0.061594992876052856 val loss 0.2582603693008423
# Epoch 43: train loss 0.05504312366247177 val loss 0.2586972713470459
# Epoch 44: train loss 0.057049017399549484 val loss 0.29132193326950073
# Epoch 45: train loss 0.05519755929708481 val loss 0.2660840153694153
# Epoch 46: train loss 0.05874981731176376 val loss 0.26155757904052734
# Epoch 47: train loss 0.05934835225343704 val loss 0.28053516149520874
# Epoch 48: train loss 0.04611608013510704 val loss 0.2937035858631134
# Epoch 49: train loss 0.0599493645131588 val loss 0.2664797306060791
# Finished in 1090.9257s.

# %%
# 0.0474 50 epoch
plot_predictions(np.hstack(all_train_ys), np.hstack(all_train_y_hats), alpha=0.01)
plt.savefig(fig_folder + data_name + "_cartesian_cv_train.pdf")
print("Avg Mean Variance:",  np.mean(all_vars))
# Out:
# Avg Mean Variance: 0.004140262

# %%
# 0.2758 50 epoch
plot_predictions(np.hstack(all_ys), np.hstack(all_y_hats), alpha=0.01)
plt.savefig(fig_folder + data_name + "_cartesian_cv_test.pdf")
print("Avg Mean Variance:",  np.mean(all_train_vars))
# Out:
# Avg Mean Variance: 0.00405932

# %% [markdown]
# ### Spherical

# %%
seed_everything()
all_ys = []
all_y_hats = []
all_vars = []

all_train_ys = []
all_train_y_hats = []
all_train_vars = []

for train_indices, test_indices in KFold(n_splits=5, shuffle=True).split(df):
    
    train_df = df.iloc[train_indices]
    test_df = df.iloc[test_indices]

    net = VoxelNet(nchannel)
    net = net.to(device)
    
    ml_train = MolLoader(train_df, sigma=sigma, elements=elements,
                     L=L, N=N, batch_size=64, nchannel=nchannel,
                     shuffle=True, rotate_randomly=True, reflect_randomly=True,
                     reduce_data=True, device=device, mode='spherical')

    ml_test = MolLoader(test_df, sigma=sigma, elements=elements,
                    L=L, N=N, batch_size=128, nchannel=nchannel,
                    shuffle=False, rotate_randomly=False, reflect_randomly=False,
                    device=device, reduce_data=True, mode='spherical')
    
    fit(epochs, net, ml_train, ml_test, torch.optim.Adam, lr=0.001, weight_decay=0)
    
    ml_pred = ml_train
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys, y_hats)
    plt.show()
    all_train_ys.append(ys)
    all_train_y_hats.append(y_hats)
    all_train_vars.append(np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
    
    ml_pred = ml_test
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys, y_hats)
    plt.show()
    all_ys.append(ys)
    all_y_hats.append(y_hats)
    all_vars.append(np.mean(np.var(y_hats.reshape(5,-1), axis=0)))
# Out:
# Initialised MolLoader with 1586 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=spherical, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 397 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=spherical, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Epoch 0: train loss 9.488926887512207 val loss 3.085268497467041
# Epoch 1: train loss 2.3933258056640625 val loss 2.129666566848755
# Epoch 2: train loss 1.9908188581466675 val loss 1.7982884645462036
# Epoch 3: train loss 1.6012063026428223 val loss 1.1407899856567383
# Epoch 4: train loss 0.689279317855835 val loss 0.6615565419197083
# Epoch 5: train loss 0.4566071629524231 val loss 0.44905856251716614
# Epoch 6: train loss 0.3697836101055145 val loss 0.42766085267066956
# Epoch 7: train loss 0.36190468072891235 val loss 0.429608553647995
# Epoch 8: train loss 0.37950244545936584 val loss 0.4213084578514099
# Epoch 9: train loss 0.35115188360214233 val loss 0.39898669719696045
# Epoch 10: train loss 0.3345179855823517 val loss 0.37851986289024353
# Epoch 11: train loss 0.3195904791355133 val loss 0.39335522055625916
# Epoch 12: train loss 0.31160229444503784 val loss 0.3681841194629669
# Epoch 13: train loss 0.3047539293766022 val loss 0.3617280125617981
# Epoch 14: train loss 0.292450875043869 val loss 0.37197065353393555
# Epoch 15: train loss 0.3076530396938324 val loss 0.3952934145927429
# Epoch 16: train loss 0.28189817070961 val loss 0.3613724112510681
# Epoch 17: train loss 0.27171948552131653 val loss 0.35384267568588257
# Epoch 18: train loss 0.2568804621696472 val loss 0.3420223295688629
# Epoch 19: train loss 0.25131645798683167 val loss 0.3391455411911011
# Epoch 20: train loss 0.2423774003982544 val loss 0.3476376235485077
# Epoch 21: train loss 0.23452766239643097 val loss 0.33158910274505615
# Epoch 22: train loss 0.25256648659706116 val loss 0.33183616399765015
# Epoch 23: train loss 0.21148821711540222 val loss 0.3269073963165283
# Epoch 45: train loss 0.051961734890937805 val loss 0.21956658363342285
# Epoch 46: train loss 0.06002538278698921 val loss 0.21275529265403748
# Epoch 47: train loss 0.06265988200902939 val loss 0.22745178639888763
# Epoch 48: train loss 0.06332140415906906 val loss 0.22746947407722473
# Epoch 49: train loss 0.06831270456314087 val loss 0.21598969399929047
# Finished in 1815.1899s.

# %%
# 0.0502 50 epoch
plot_predictions(np.hstack(all_train_ys), np.hstack(all_train_y_hats), alpha=0.01)
plt.savefig(fig_folder + data_name + "_spherical_cv_train.pdf")
print("Avg Mean Variance:",  np.mean(all_vars))
# Out:
# Avg Mean Variance: 0.0005184454

# %%
# 0.2707 50 epoch
plot_predictions(np.hstack(all_ys), np.hstack(all_y_hats), alpha=0.01)
plt.savefig(fig_folder + data_name + "_spherical_cv_test.pdf")
print("Avg Mean Variance:",  np.mean(all_train_vars))
# Out:
# Avg Mean Variance: 0.00048161997

# %% [markdown]
# ## Parameter Grid Search

# %%
seed_everything()
train_df, test_df = train_test_split(df, test_size=0.1)
print(train_df.shape, test_df.shape)
# Out:
# (1784, 13) (199, 13)

# %%
param_grid = ParameterGrid({
    "sigma": [0.01, 0.1, 0.5, 1.],
    "L": [10, 12.8, 15],
    "weight_decay": [0., 0.001, 0.01]
})

# %%
len(list(param_grid))
# Out:
# 36

# %%
device = get_default_device()

results = []

for i, params in enumerate(param_grid):
    L = params["L"]
    sigma = params["sigma"]
    weight_decay = params["weight_decay"]
    print(f"{i}. L = {L}, sigma = {sigma}, weight_decay = {weight_decay}")

    seed_everything()
    
    net = VoxelNet(nchannel)
    net = net.to(device)

    ml_train = MolLoader(train_df, sigma=sigma, elements=elements,
                     L=L, N=N, batch_size=64, nchannel=nchannel,
                     shuffle=True, rotate_randomly=True, reflect_randomly=True,
                     reduce_data=True, device=device, mode='cartesian')

    ml_test = MolLoader(test_df, sigma=sigma, elements=elements,
                    L=L, N=N, batch_size=128, nchannel=nchannel,
                    shuffle=False, rotate_randomly=False, reflect_randomly=False,
                    device=device, reduce_data=True, mode='cartesian')
    
    fit(epochs, net, ml_train, ml_test, torch.optim.Adam, lr=0.001, weight_decay=weight_decay, verbose=False)
    
    ml_pred = ml_train
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys_train, y_hats_train = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys_train, y_hats_train)
    plt.show()
    
    ml_pred = ml_test
    ml_pred.reset(batch_size=128, shuffle=False, rotate_randomly=True, reflect_randomly=True)
    ys, y_hats = predict_epochs(net, ml_pred, epochs=5)
    plot_predictions(ys, y_hats)
    plt.show()
    
    results.append({"train": np.mean((ys_train - y_hats_train)**2), "test": np.mean((ys - y_hats)**2)})
# Out:
# 0. L = 10, sigma = 0.01, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1862.6266s.
# 1. L = 10, sigma = 0.01, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1850.9633s.
# 2. L = 10, sigma = 0.01, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1836.7041s.
# 3. L = 10, sigma = 0.1, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1832.0225s.
# 4. L = 10, sigma = 0.1, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1802.8132s.
# 5. L = 10, sigma = 0.1, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1833.2051s.
# 6. L = 10, sigma = 0.5, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1822.1025s.
# 7. L = 10, sigma = 0.5, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1808.6471s.
# 8. L = 10, sigma = 0.5, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1843.8890s.
# 9. L = 10, sigma = 1.0, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1849.3308s.
# 10. L = 10, sigma = 1.0, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1841.1999s.
# 11. L = 10, sigma = 1.0, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=10, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1773.1651s.
# 12. L = 12.8, sigma = 0.01, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1090.5995s.
# 13. L = 12.8, sigma = 0.01, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1117.4228s.
# 14. L = 12.8, sigma = 0.01, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1115.4658s.
# 15. L = 12.8, sigma = 0.1, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1127.3868s.
# 16. L = 12.8, sigma = 0.1, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1111.4958s.
# 17. L = 12.8, sigma = 0.1, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1081.8223s.
# 18. L = 12.8, sigma = 0.5, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1073.2336s.
# 19. L = 12.8, sigma = 0.5, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1108.8624s.
# 20. L = 12.8, sigma = 0.5, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1109.9061s.
# 21. L = 12.8, sigma = 1.0, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1072.0142s.
# 22. L = 12.8, sigma = 1.0, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1076.3440s.
# 23. L = 12.8, sigma = 1.0, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=12.8, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 1066.0527s.
# 24. L = 15, sigma = 0.01, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 945.2335s.
# 25. L = 15, sigma = 0.01, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 947.9152s.
# 26. L = 15, sigma = 0.01, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.01, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 945.6376s.
# 27. L = 15, sigma = 0.1, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 939.7823s.
# 28. L = 15, sigma = 0.1, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 937.9330s.
# 29. L = 15, sigma = 0.1, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.1, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 933.9991s.
# 30. L = 15, sigma = 0.5, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 898.8173s.
# 31. L = 15, sigma = 0.5, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 912.9821s.
# 32. L = 15, sigma = 0.5, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=0.5, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 935.6519s.
# 33. L = 15, sigma = 1.0, weight_decay = 0.0
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 905.4466s.
# 34. L = 15, sigma = 1.0, weight_decay = 0.001
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 901.2817s.
# 35. L = 15, sigma = 1.0, weight_decay = 0.01
# Initialised MolLoader with 1784 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=True, rotate=True, reflect=True
# Initialised MolLoader with 199 compounds.
#     sigma=1.0, L=15, N=32, nchannel=79, mode=cartesian, device=cuda
#     shuffle=False, rotate=False, reflect=False
# Finished in 933.3762s.

# %%
for param, mse in zip(param_grid, results):
    print(param, mse)
# Out:
# {'L': 10, 'sigma': 0.01, 'weight_decay': 0.0} {'train': 0.035017807, 'test': 0.28448877}
# {'L': 10, 'sigma': 0.01, 'weight_decay': 0.001} {'train': 0.03427867, 'test': 0.2700884}
# {'L': 10, 'sigma': 0.01, 'weight_decay': 0.01} {'train': 0.07277016, 'test': 0.2630417}
# {'L': 10, 'sigma': 0.1, 'weight_decay': 0.0} {'train': 0.06466632, 'test': 0.30143285}
# {'L': 10, 'sigma': 0.1, 'weight_decay': 0.001} {'train': 0.039879374, 'test': 0.27133214}
# {'L': 10, 'sigma': 0.1, 'weight_decay': 0.01} {'train': 0.08458535, 'test': 0.24721803}
# {'L': 10, 'sigma': 0.5, 'weight_decay': 0.0} {'train': 0.18506429, 'test': 0.33157858}
# {'L': 10, 'sigma': 0.5, 'weight_decay': 0.001} {'train': 0.18603373, 'test': 0.3440775}
# {'L': 10, 'sigma': 0.5, 'weight_decay': 0.01} {'train': 0.1933799, 'test': 0.3681138}
# {'L': 10, 'sigma': 1.0, 'weight_decay': 0.0} {'train': 0.20787483, 'test': 0.36074194}
# {'L': 10, 'sigma': 1.0, 'weight_decay': 0.001} {'train': 0.18373722, 'test': 0.35806054}
# {'L': 10, 'sigma': 1.0, 'weight_decay': 0.01} {'train': 2.19736, 'test': 2.3807135}
# {'L': 12.8, 'sigma': 0.01, 'weight_decay': 0.0} {'train': 0.033484515, 'test': 0.26867554}
# {'L': 12.8, 'sigma': 0.01, 'weight_decay': 0.001} {'train': 0.07753731, 'test': 0.31169197}
# {'L': 12.8, 'sigma': 0.01, 'weight_decay': 0.01} {'train': 0.090558134, 'test': 0.28585854}
# {'L': 12.8, 'sigma': 0.1, 'weight_decay': 0.0} {'train': 0.04237953, 'test': 0.27624443}
# {'L': 12.8, 'sigma': 0.1, 'weight_decay': 0.001} {'train': 0.091175035, 'test': 0.2999511}
# {'L': 12.8, 'sigma': 0.1, 'weight_decay': 0.01} {'train': 0.10612232, 'test': 0.300308}
# {'L': 12.8, 'sigma': 0.5, 'weight_decay': 0.0} {'train': 0.154759, 'test': 0.32340685}
# {'L': 12.8, 'sigma': 0.5, 'weight_decay': 0.001} {'train': 0.17015556, 'test': 0.33242315}
# {'L': 12.8, 'sigma': 0.5, 'weight_decay': 0.01} {'train': 0.20130911, 'test': 0.3662783}
# {'L': 12.8, 'sigma': 1.0, 'weight_decay': 0.0} {'train': 0.19513609, 'test': 0.3577319}
# {'L': 12.8, 'sigma': 1.0, 'weight_decay': 0.001} {'train': 0.19750957, 'test': 0.39549482}
# {'L': 12.8, 'sigma': 1.0, 'weight_decay': 0.01} {'train': 2.197212, 'test': 2.3806436}
# {'L': 15, 'sigma': 0.01, 'weight_decay': 0.0} {'train': 0.068166934, 'test': 0.3068999}
# {'L': 15, 'sigma': 0.01, 'weight_decay': 0.001} {'train': 0.09808803, 'test': 0.31972712}
# {'L': 15, 'sigma': 0.01, 'weight_decay': 0.01} {'train': 0.1143036, 'test': 0.3132905}
# {'L': 15, 'sigma': 0.1, 'weight_decay': 0.0} {'train': 0.045084376, 'test': 0.2799397}
# {'L': 15, 'sigma': 0.1, 'weight_decay': 0.001} {'train': 0.102852225, 'test': 0.3245347}
# {'L': 15, 'sigma': 0.1, 'weight_decay': 0.01} {'train': 0.162752, 'test': 0.34067032}
# {'L': 15, 'sigma': 0.5, 'weight_decay': 0.0} {'train': 0.14291038, 'test': 0.32180154}
# {'L': 15, 'sigma': 0.5, 'weight_decay': 0.001} {'train': 0.21258065, 'test': 0.3699904}
# {'L': 15, 'sigma': 0.5, 'weight_decay': 0.01} {'train': 0.20963113, 'test': 0.37990388}
# {'L': 15, 'sigma': 1.0, 'weight_decay': 0.0} {'train': 0.18510373, 'test': 0.35079497}
# {'L': 15, 'sigma': 1.0, 'weight_decay': 0.001} {'train': 0.18726179, 'test': 0.36680675}
# {'L': 15, 'sigma': 1.0, 'weight_decay': 0.01} {'train': 2.1972077, 'test': 2.3806434}
