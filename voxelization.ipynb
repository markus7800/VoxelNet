# %% [markdown]
# ## Crystal Structure
#
# A crystal or crystalline solid is a solid material whose constituents (such as atoms, molecules, or ions) are arranged in a highly ordered microscopic structure, forming a crystal lattice that extends in all directions.
#
# The smallest group of particles in the material that constitutes this repeating pattern is the **unit cell** of the structure. The unit cell completely reflects the symmetry and structure of the entire crystal, which is built up by **repetitive translation** of the unit cell along its **principal axes**. The translation vectors define the nodes of the **Bravais lattice**.
#
# The lengths of the principal axes, or edges, of the unit cell and the angles between them are the lattice constants, also called **lattice parameters** or **cell parameters**.
#
# ### Unit Cell
#
# Crystal structure is described in terms of the geometry of arrangement of particles in the unit cell. The unit cell is defined as the smallest repeating unit having the full symmetry of the crystal structure.
#
# The geometry of the unit cell is defined as a parallelepiped, providing six lattice parameters taken as the lengths of the cell edges $(a, b, c)$ and the angles between them $(\alpha, \beta, \gamma)$. The positions of particles inside the unit cell are described by the fractional coordinates $(x_i, y_i, z_i)$ along the cell edges, measured from a reference point.
#
#
# https://en.wikipedia.org/wiki/Crystal_structure
#
# ### Bravais lattice
# In geometry and crystallography, a Bravais lattice is an infinite array of discrete points generated by a set of discrete translation operations described in three dimensional space by:
#
#
# $\mathbf{R} = n_{1}\mathbf{a}_{1} + n_{2}\mathbf{a}_{2} + n_{3}\mathbf{a}_{3}$
#
#
# where the $n_i$ are any integers and $a_i$ are **primitive vectors** which lie in different directions (not necessarily mutually perpendicular) and span the lattice.
# A fundamental aspect of any Bravais lattice is that, for any choice of direction, the lattice will appear exactly the same from each of the discrete lattice points when looking in that chosen direction.
#
# In crystallography, the Bravais lattice concept of an infinite array of discrete points is expanded using the concept of a **unit cell** which includes the space in between the discrete lattice points as well as any atoms in that space. There are two main types of unit cells: primitive unit cells and non-primitive unit cells.
#
# A **primitive unit cell** for a given Bravais lattice can be chosen in more than one way (each way having a different shape), but each way will have the *same volume* and each way will have the property that a *one-to-one correspondence can be established between the primitive unit cells and the discrete lattice points*. The *obvious primitive cell to associate with a particular choice of primitive vectors is the parallelepiped formed by them*. That is, the set of all points r of the form:
#
# ${\displaystyle \mathbf {r} =x_{1}\mathbf {a} _{1}+x_{2}\mathbf {a} _{2}+x_{3}\mathbf {a} _{3}\qquad {\text{where }}0\leq x_{i}<1}$
#
# Using the parallelepiped defined by the primitive vectors as the unit cell has the disadvantage in some cases of not clearly revealing the full symmetry of the lattice.
# A solution is to use a **non-primitive unit cell** which does display the full symmetry of the lattice. The non-primitive unit cell volume will be an integer multiple of the primitive unit cell volume.
#
# The unit cell, whether primitive or not, when replicated once for each discrete lattice point, must exactly fill the entire space with no overlap and no gaps.
#
# A crystal is made up of a periodic arrangement of one or more atoms (the **basis** or motif) occurring exactly once in each primitive unit cell.
# Consequently, the crystal looks the same when viewed in any given direction from any equivalent points in two different unit cells (two points in two different unit cells of the same lattice are equivalent if they have the same relative position with respect to their individual unit cell boundaries).
#
# https://en.wikipedia.org/wiki/Bravais_lattice
#
# <img src="imgs/1280px-NaCl-Ionengitter.svg.png" width="300px">
#
#
# ### Defects and impurities
# Real crystals feature defects or irregularities in the ideal arrangements described above and it is these defects that critically determine many of the electrical and mechanical properties of real materials. When one atom substitutes for one of the principal atomic components within the crystal structure, alteration in the electrical and thermal properties of the material may ensue.
#
# <img src="imgs/MoS2_antisites&vacancies.jpg" width="300px">
#
# https://en.wikipedia.org/wiki/Crystallographic_defect
#
# ### Wigner–Seitz cell
#
# The unique property of a crystal is that its atoms are arranged in a regular three-dimensional array called a lattice. All the properties attributed to crystalline materials stem from this highly ordered structure. Such a structure exhibits discrete translational symmetry. In order to model and study such a periodic system, one needs a mathematical "handle" to describe the symmetry and hence draw conclusions about the material properties consequent to this symmetry. The Wigner–Seitz cell is a means to achieve this.
#
# A Wigner–Seitz cell is an example of a primitive cell, which is a **unit cell containing exactly one lattice point.** For any given lattice, there are an infinite number of possible primitive cells. However there is only one Wigner–Seitz cell for any given lattice. It is the locus of points in space that are closer to that lattice point than to any of the other lattice points.
#
# https://en.wikipedia.org/wiki/Wigner–Seitz_cell
#
# ### Symmetry groups
#
# #### Point groups
#
# The crystallographic point group or crystal class is the mathematical group comprising the symmetry operations that leave at least one point unmoved and that leave the appearance of the crystal structure unchanged. These symmetry operations include
#
# - Reflection, which reflects the structure across a reflection plane
# - Rotation, which rotates the structure a specified portion of a circle about a rotation axis
# - Inversion, which changes the sign of the coordinate of each point with respect to a center of symmetry or inversion point
# - Improper rotation, which consists of a rotation about an axis followed by an inversion.
#
#
# #### Space groups
# In addition to the operations of the point group, the space group of the crystal structure contains translational symmetry operations. These include:
#
# - Pure translations, which move a point along a vector
# - Screw axes, which rotate a point around an axis while translating parallel to the axis.
# - Glide planes, which reflect a point through a plane while translating it parallel to the plane.
#
# https://en.wikipedia.org/wiki/Crystal_structure
#
# ### Reciprocal lattice
# In physics, the reciprocal lattice represents the Fourier transform of another lattice (usually a Bravais lattice). In normal usage, the initial lattice (whose transform is represented by the reciprocal lattice) is usually a periodic spatial function in real-space and is also known as the direct lattice.
#
# While the direct lattice exists in real-space and is what one would commonly understand as a physical lattice, the reciprocal lattice exists in reciprocal space.
# The reciprocal lattice of a reciprocal lattice is equivalent to the original direct lattice, because the defining equations are symmetrical with respect to the vectors in real and reciprocal space. Mathematically, direct and reciprocal lattice vectors represent covariant and contravariant vectors, respectively.
#
# #### Reciprocal space
# Reciprocal space provides a way to visualise the results of the Fourier transform of a spatial function. The domain of the spatial function itself is often referred to as real space.
# Whereas these spatial dimensions will be the same, the spaces will differ in their units, so that when the real space has units of length L, its reciprocal space will have corresponding units of one divided by length L−1 (the reciprocal of length).
#
# In three dimensions, the corresponding  sinusoidal plane wave  term becomes
# ${\displaystyle \cos {(\mathbf {k} {\cdot }\mathbf {r} {-}\omega t{+}\phi _{0})}}$,
# which simplifies to
# ${\displaystyle \cos {(\mathbf {k} {\cdot }\mathbf {r} {+}\phi )}}$
#
# at a fixed time
# $t$, where
# $\mathbf{r}$  is the position vector of a point in real space and now
# ${\displaystyle \mathbf {k} =2\pi \mathbf {e} /\lambda }$ is the wavevector in the three dimensional reciprocal space.
# The constant
# $\phi$ is the phase of the wavefront (plane of constant phase) through the origin at time
# $t$, and
# $\mathbf{e}$  is a unit vector perpendicular to this wavefront. The wavefronts with phase
# $\phi$  comprise a set of parallel planes, equally spaced by the wavelength
# $\lambda$.
#
# #### Reciprocal lattice
# In general, a geometric lattice consists of an infinite, regular array of vertices in space, which can be modelled vectorially as a Bravais lattice.
#
# A **reciprocal lattice** is the periodic set of the wave vectors
# $\mathbf {k}$  in reciprocal space that make up the Fourier series of any function
# $f(\mathbf{r})$ whose periodicity is compatible with that of an initial direct lattice in real space. Equivalently, a wavevector is a vertex of the reciprocal lattice if it corresponds to a plane wave in real space whose phase at any given time is the same at every direct lattice vertex.
#
# One heuristic approach to constructing the reciprocal lattice in three dimensions is to write the position vector of a vertex of the direct lattice as
#
# ${\displaystyle \mathbf {R} =n_{1}\mathbf {a} _{1}{+}n_{2}\mathbf {a} _{2}{+}n_{3}\mathbf {a} _{3}}$,
#
# where the
# $n_{i}$ are integers defining the vertex and the
# $\mathbf{a}_i$ are linearly independent primitive vectors characteristic of the lattice.
#
# There is then a unique plane wave (up to a factor of negative one), whose wavefront through the origin contains the direct lattice points at
# $\mathbf {a} _{2}$ and
# $\mathbf {a} _{3}$, and with its adjacent wavefront passing through
# $\mathbf {a} _{1}$. Its angular wavevector takes the form
# ${\displaystyle \mathbf {b} _{1}=2\pi \mathbf {e} _{1}/\lambda _{1}}$, where
# $\mathbf {e} _{1}$ is the unit vector perpendicular to these two wavefronts and the wavelength
# $\lambda _{1}$ must satisfy
# ${\displaystyle \lambda _{1}=\mathbf {a} _{1}\cdot \mathbf {e} _{1}}$. Hence by construction
# ${\displaystyle \mathbf {a} _{1}\cdot \mathbf {b} _{1}=2\pi }$ and
# ${\displaystyle \mathbf {a} _{2}\cdot \mathbf {b} _{1}=\mathbf {a} _{3}\cdot \mathbf {b} _{1}=0}$.
#
# Cycling through the indices in turn, the same method yields three wavevectors
# ${\displaystyle \mathbf {b} _{j}}$ with
# ${\displaystyle \mathbf {a} _{i}\cdot \mathbf {b} _{j}=2\pi \,\delta _{ij}}$.
# The ${\displaystyle \mathbf {b} _{j}}$ comprise a set of three primitive wavevectors for the reciprocal lattice, each of whose vertices takes the form
#
# ${\displaystyle \mathbf {G} =m_{1}\mathbf {b} _{1}{+}m_{2}\mathbf {b} _{2}{+}m_{3}\mathbf {b} _{3}}$,
#
# where the
# $m_{j}$ are integers.
#
# Simple algebra then shows that, for any plane wave with wavevector
# $\mathbf {G}$  on the reciprocal lattice, the total phase shift
# ${\displaystyle \mathbf {G} \cdot \mathbf {R} }$ between the origin and any point
# $\mathbf {R}$  on the direct lattice is a (possibly zero) multiple of
# $2\pi$ , so the phase will indeed be equal for every direct lattice vertex, in conformity with the reciprocal lattice definition above.
#
# #### Maths
#
# Taking a function
# $f(\mathbf{r})$ where
# $\mathbf {r}$  is a vector from the origin to any position, if
# $f(\mathbf{r})$ follows the periodicity of the lattice, e.g. the electronic density in an atomic crystal, it is useful to write
# $f(\mathbf{r})$ as a multi-dimensional Fourier series
#
# ${\displaystyle \sum _{m}{f_{m}\exp({i\mathbf {G} _{m}\cdot \mathbf {r} }})=f\left(\mathbf {r} \right)}$
#
#
# where now the subscript
# ${\displaystyle m=(m_{1},m_{2}, m_{3})}$.
#
# As
# $f(\mathbf{r})$ follows the periodicity of the lattice, translating
# $\mathbf {r}$  by any lattice vector
# ${\mathbf  {R}}_{n}$ we get the same value, hence
#
# ${\displaystyle f(\mathbf {r} +\mathbf {R} _{n})=f(\mathbf {r} )}$.
#
# Expressing the above instead in terms of their Fourier series we have
#
# ${\displaystyle \sum _{m}{f_{m}\exp({i\mathbf {G} _{m}\cdot \mathbf {r} }})=
# \sum _{m}{f_{m}\exp({i\mathbf {G} _{m}\cdot (\mathbf {r} +\mathbf {R} _{n})}})=
# \sum _{m}{f_{m}\exp({i\mathbf {G} _{m}\cdot \mathbf {R} _{n}})\,\exp({i\mathbf {G} _{m}\cdot \mathbf {r} })}}$
#
# Because equality of two Fourier series implies equality of their coefficients,
# ${\displaystyle \exp({i\mathbf {G} _{m}\cdot \mathbf {R} _{n}})=1}$, which only holds when
# ${\displaystyle \mathbf {G} _{m}\cdot \mathbf {R} _{n}=2\pi N}$ where
# ${\displaystyle N\in \mathbb {Z} .}$
# This criterion restricts the values of
# ${\displaystyle \mathbf {G} _{m}}$ to vectors that satisfy this relation.
#
# Mathematically, the reciprocal lattice is the set of all vectors
# ${\displaystyle \mathbf {G} _{m}}$ that satisfy the above identity for all lattice point position vectors
# ${\mathbf  {R}}_{n}$. As such, any function which exhibits the same periodicity of the lattice can be expressed as a Fourier series with angular frequencies taken from the reciprocal lattice.
#
# The "crystallographer's" definition, for the scalar triple product
# ${\displaystyle V=\mathbf {a} _{1}\cdot \left(\mathbf {a} _{2}\times \mathbf {a} _{3}\right)}$:
#
# ${\displaystyle {\begin{aligned}\mathbf {b} _{1}&={\frac {2\pi }{V}}\ \mathbf {a} _{2}\times \mathbf {a} _{3}\\\mathbf {b} _{2}&={\frac {2\pi }{V}}\ \mathbf {a} _{3}\times \mathbf {a} _{1}\\\mathbf {b} _{3}&={\frac {2\pi }{V}}\ \mathbf {a} _{1}\times \mathbf {a} _{2}\end{aligned}}}$
#
# or the "physics" definition
#
# ${\displaystyle \left[\mathbf {b} _{1}\mathbf {b} _{2}\mathbf {b} _{3}\right]^{\mathsf {T}}=2\pi \left[\mathbf {a} _{1}\mathbf {a} _{2}\mathbf {a} _{3}\right]^{-1}.}$
#
# Each point
# $(hkl)$ in the reciprocal lattice corresponds to a set of lattice planes
# $(hkl)$ in the real space lattice. The direction of the reciprocal lattice vector corresponds to the normal to the real space planes. The magnitude of the reciprocal lattice vector is given in reciprocal length and is equal to the reciprocal of the interplanar spacing of the real space planes.
#
# <img src="imgs/Lattice_waves.png" width="600px">
# A real space 2D lattice (red dots) with primitive vectors
# $a_{1}$ and
# $a_{2}$ are shown by blue and green arrows respectively.
#
# From this we see that when
# $G$ is any integer combination of reciprocal lattice vector basis
# $b_{1}$ and
# $b_{2}$ (i.e. any reciprocal lattice vector), the resulting plane waves have the same periodicity of the lattice - that is that any translation from point
# $r$ (shown orange) to a point
# $R+r$ (
# $R$ shown red), the value of the plane wave is the same. These plane waves can be added together and the above relation will still apply.
#
# https://en.wikipedia.org/wiki/Reciprocal_lattice

# %%
import json
from urllib.request import urlopen
SERVER="http://aflowlib.duke.edu"
PROJECT="AFLOWDATA/LIB3_RAW/"

#URL=SERVER+’/’+PROJECT
#URL=SERVER+’/’+PROJECT+’AlCu_pvMn_pv/’
URL=SERVER+"/"+PROJECT+"AlCu_pvMn_pv/T0001.A2BC/"

entry=json.loads(urlopen(URL+"?format=json").read().decode("utf-8"))

for key in entry:
    print("{}={}".format (key, entry[key]))


coords = entry["positions_cartesian"]

# %%
entry["natoms"]

# %%
entry["compound"]

# %%
entry["species"]

# %%
entry["composition"]

# %%
entry["positions_cartesian"]

# %%
entry["geometry_orig"]

# %%
entry["geometry"]

# %%
entry["reciprocal_geometry_orig"]

# %%
entry["reciprocal_geometry"]

# %%
# http://aflowlib.duke.edu/aflowwiki/doku.php?id=documentation:all_keywords
# icsd: Inorganic Crystal Structure Database

print(entry["code"])

# Final Cartesian positions (x_i,x_j,x_k) in the notation of the code.
print(entry["positions_cartesian"])

# Returns geometrical data describing the unit cell in the usual a,b,c, α, β, γ notation, 
# Units: a, b, c are the natural units of the $code, α, β, γ are in degrees.
# vasp -> Angstrom, qe -> a.u. (bohr)
print(entry["geometry"])

print(entry["geometry_orig"])

# Final fractional positions (x_i,x_j,x_k) with respect to the unit cell as specified in $geometry.
print(entry["positions_fractional"])


print(entry["reciprocal_geometry"])

# Returns the number of atoms in the unit cell of the structure entry
print(entry["natoms"])

# %%
coords

# %%
str_coords = list(map(lambda s: s.split(","), coords.split(";")))
str_coords

# %%
import numpy as np

# %%
coords = np.array(str_coords).astype(np.float)
coords

# %%
coords.shape

# %% [markdown]
# ## One centered sphere

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def theoretical(R, gx, gy):
    d = np.sqrt(gx*gx + gy*gy)
    if d == 0:
        return 4*np.pi * R**3 / 3
    
    return 4*np.pi/d**3 * (np.sin(d*R)-d*R*np.cos(d*R))

# %%
n = 2*16+1
discrete_theoretical = np.zeros((n,n), dtype=np.complex128)
gxs = np.arange(-16,16+1)
gys = np.arange(-16,16+1)
for i, x in enumerate(gxs):
    for j, y in enumerate(gys):
        discrete_theoretical[i,j] = theoretical(0.25, 2*np.pi * x, 2*np.pi * y)

# %%
plt.figure(figsize=(5,4))
plt.pcolormesh(gxs, gys, np.abs(discrete_theoretical), shading='auto')
plt.colorbar()
plt.show()

# %%
def spheres(r, v):
    x = v[0]
    y = v[1]
    
    cx = np.round(x)
    cy = np.round(y)
    
    if (x-cx)**2 + (y-cy)**2 < r**2:
        return 1.
    else:
        return 0.
    
def get_spheres_field(r, offset):
    def F(v):
        v += offset
        return spheres(r, v)
    return F

# %%
centered_sphere = get_spheres_field(0.25, offset=np.array([0.5,0.5]))
corner_spheres = get_spheres_field(0.25, offset=np.array([0.,0.]))

# %%
def bravais_lattice(s, A, n=101, d=2):
    xi = np.linspace(0,1,n)
    
    if d == 2:
        x1, x2 = np.meshgrid(xi, xi)
        X = np.vstack((x1.reshape(1,-1), x2.reshape(1,-1))) # (2,n*n)
        
    R = A.dot(X) # (2,n*n)
        
    SR = np.apply_along_axis(s, 0, R) # apply field column-wise, (1,n*n)
    
    SR = SR.reshape(n,n)
    
    return (xi, SR)

# %%
def reciprocal_lattice(s, A, n=101, g0=-16, g1=16, d=2):
    
    B = 2*np.pi * np.linalg.inv(A).T
    print("B:\n", B)
    
    xi = np.linspace(0,1,n)
    mi = np.arange(g0,g1+1)
    m = len(mi)
    
    if d == 2:
        x1, x2 = np.meshgrid(xi, xi)
        X = np.vstack((x1.reshape(1,-1), x2.reshape(1,-1))) # (2,n*n)
        print("X", X.shape)
        
        m1, m2 = np.meshgrid(mi, mi)
        M = np.vstack((m1.reshape(1,-1), m2.reshape(1,-1))) # (2,m*m)
        print("M", M.shape)

        
    R = A.dot(X) # (2,n*n)
    G = B.dot(M) # (2,m*m)
    
    XR = R.T.dot(G) # (n*n, m*m) (=2 * np.pi * X.T.dot(M))
    # print(XR)
    # print(2 * np.pi * X.T.dot(M))
    
    E = np.exp(-1j * XR) # (n*n, m*m)
    print("XR", XR.shape)
    print("E", E.shape)

    SR = np.apply_along_axis(s, 0, R) # apply field column-wise, (n*n,)
    print("SR", SR.shape)

    delta = (xi[1] - xi[0])**d
    SG = delta * SR.dot(E) # (m*m,)
    print("SG", SG.shape)
    
    SG = SG.reshape(m,m)
    
    return (B, mi, SG)

# %%
def plot_2D_realspace_lattice(A, xi, SR):
    n = len(xi)
    x1, x2 = np.meshgrid(xi, xi)
    X = np.vstack((x1.reshape(1,-1), x2.reshape(1,-1))) # (2,n*n)
    R = A.dot(X)
    r1 = R[0,:].reshape(n,n)
    r2 = R[1,:].reshape(n,n)
    
    l1 = np.abs(r1).max()
    l2 = np.abs(r2).max()

    plt.figure(figsize=(4 * l1/l2,4))
    plt.pcolormesh(r1, r2, SR, shading='auto')
    plt.show()

# %%
def plot_2D_bravais_lattice(A, xi, SR):
    plt.figure(figsize=(4,4))
    plt.pcolormesh(xi, xi, SR, shading='auto')
    
    plt.xlabel(f"a1 = ({A[0,0]:.2f}, {A[1,0]:.2f})")
    plt.ylabel(f"a2 = ({A[0,1]:.2f}, {A[1,1]:.2f})")
    plt.show()

# %%
def plot_2D_reciprocal_lattice(B, mi, SG, xlims=None, ylims=None):
    absSG = np.abs(SG)
    
    plt.figure(figsize=(5,4))
    plt.pcolormesh(mi, mi, absSG, shading='auto')
    plt.colorbar()
    
    plt.xlabel(f"b1 = ({B[0,0]:.2f}, {B[1,0]:.2f})")
    plt.ylabel(f"b2 = ({B[0,1]:.2f}, {B[1,1]:.2f})")
    
    plt.show()
    
    plt.figure(figsize=(4,4))
    m1, m2 = np.meshgrid(mi, mi)
    M = np.vstack((m1.reshape(1,-1), m2.reshape(1,-1)))
    G = B.dot(M)
    
    max_sg = absSG.max()
    colors = [(1.,0.,0.,v) for v in absSG.reshape(-1) / max_sg]
    plt.scatter(G[0,:], G[1,:], c=colors)
    if xlims:
        plt.xlim(xlims)
    if ylims:
        plt.ylim(ylims)
    
    plt.show()

# %%
A = np.eye(2)
A
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
xi, sr = bravais_lattice(centered_sphere, A)

# %%
plot_2D_bravais_lattice(A, xi, sr)

# %%
# %%time
B, mi, sg = reciprocal_lattice(centered_sphere, A, g0=-16, g1=16)
# Out:
# B:
#  [[6.28318531 0.        ]
#  [0.         6.28318531]]
# X (2, 10201)
# M (2, 1089)
# XR (10201, 1089)
# E (10201, 1089)
# SR (10201,)
# SG (1089,)
# CPU times: user 696 ms, sys: 171 ms, total: 867 ms
# Wall time: 783 ms

# %%
plot_2D_reciprocal_lattice(B, mi, sg)

# %%
xi, sr = bravais_lattice(corner_spheres, A)

# %%
plot_2D_bravais_lattice(A, xi, sr)

# %%
# %%time
B, mi, sg = reciprocal_lattice(corner_spheres, A, g0=-16, g1=16)
# Out:
# B:
#  [[6.28318531 0.        ]
#  [0.         6.28318531]]
# X (2, 10201)
# M (2, 1089)
# XR (10201, 1089)
# E (10201, 1089)
# SR (10201,)
# SG (1089,)
# CPU times: user 627 ms, sys: 139 ms, total: 766 ms
# Wall time: 692 ms

# %%
plot_2D_reciprocal_lattice(B, mi, sg)

# %%
A = np.array([
    [1., 1.],
    [0., 1.]
])

# %%
xi, sr = bravais_lattice(corner_spheres, A)

# %%
plot_2D_realspace_lattice(A, xi, sr)

# %%
plot_2D_bravais_lattice(A, xi, sr)

# %%
# %%time
B, mi, sg = reciprocal_lattice(corner_spheres, A, g0=-16, g1=16)
# Out:
# B:
#  [[ 6.28318531  0.        ]
#  [-6.28318531  6.28318531]]
# X (2, 10201)
# M (2, 1089)
# XR (10201, 1089)
# E (10201, 1089)
# SR (10201,)
# SG (1089,)
# CPU times: user 695 ms, sys: 167 ms, total: 862 ms
# Wall time: 731 ms

# %%
plot_2D_reciprocal_lattice(B, mi, sg, ylims=(-100.,100))

# %%
def custom_points(r, ps):
    def F(v):
        for p in ps:
            if np.linalg.norm(v - p) < r:
                return 1.
        return 0.
    return F

# %%
s = custom_points(0.25,
                  [
                      [0.,0.], [2.,2.], [0.,2.], [2.,0.],
                      [1,0.0], [1, 2.], [0.0, 1.], [2., 1.],
                      [1.,1.]
                  ])
A = np.eye(2) * 2

# %%
# %%time
xi, sr = bravais_lattice(s, A)
plot_2D_bravais_lattice(A, xi, sr)

B, mi, sg = reciprocal_lattice(s, A, g0=-32, g1=32)
plot_2D_reciprocal_lattice(B, mi, sg)
# Out:
# B:
#  [[3.14159265 0.        ]
#  [0.         3.14159265]]
# X (2, 10201)
# M (2, 4225)
# XR (10201, 4225)
# E (10201, 4225)
# SR (10201,)
# SG (4225,)
# CPU times: user 4.35 s, sys: 1.74 s, total: 6.09 s
# Wall time: 6.67 s

# %%
A = np.eye(2) * 2
xi, sr = bravais_lattice(corner_spheres, A)
plot_2D_bravais_lattice(A, xi, sr)

B, mi, sg = reciprocal_lattice(corner_spheres, A, g0=-32, g1=32)
plot_2D_reciprocal_lattice(B, mi, sg)
# Out:
# B:
#  [[3.14159265 0.        ]
#  [0.         3.14159265]]
# X (2, 10201)
# M (2, 4225)
# XR (10201, 4225)
# E (10201, 4225)
# SR (10201,)
# SG (4225,)

# %%
s = custom_points(0.2, [[0.,0.], [1.,1.], [0.,1.], [1.,0.], [0.5, 0.3], [0.3, 0.5], [0.5, 0.7], [0.7, 0.5]])
A = np.eye(2)

# %%
# %%time
xi, sr = bravais_lattice(s, A)
plot_2D_bravais_lattice(A, xi, sr)

B, mi, sg = reciprocal_lattice(s, A, g0=-8, g1=8)
plot_2D_reciprocal_lattice(B, mi, sg)
# Out:
# B:
#  [[6.28318531 0.        ]
#  [0.         6.28318531]]
# X (2, 10201)
# M (2, 289)
# XR (10201, 289)
# E (10201, 289)
# SR (10201,)
# SG (289,)
# CPU times: user 2.25 s, sys: 232 ms, total: 2.48 s
# Wall time: 2.53 s

# %%
# dont represent in g coordinates but enbed g in canonical
# scale unit cell to |a_i|=1?, warps gaussians

# %%
# only integer multiples of g??
# transform, such that A = Identity, such that B = 2pi * Identity (same resulution for all)
